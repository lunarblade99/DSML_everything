# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
x=[np.exp(i) for i in range(10)]
y=[i for i in range(10)]
plt.plot(y,x)

# %%
df = pd.read_csv('movies.csv')
df
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
y = df['day'].value_counts().to_list()
x = df['day'].value_counts().index
plt.figure(figsize=(12,8))
plt.xticks(rotation=90,fontsize=12)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Top Genres & there counts')
plt.bar(x,y,width=0.3,color='orange')
# Out:
# <BarContainer object of 7 artists>

# %%
sns.countplot(data=df,x='day',order=df['day'].value_counts().index)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Friday'),
#   Text(1, 0, 'Thursday'),
#   Text(2, 0, 'Wednesday'),
#   Text(3, 0, 'Tuesday'),
#   Text(4, 0, 'Monday'),
#   Text(5, 0, 'Saturday'),
#   Text(6, 0, 'Sunday')])

# %%
sales = pd.read_csv('sales.csv')
sales.order.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
y = sales['Description'].value_counts().to_list()
x = sales['Description'].value_counts().index
plt.figure(figsize=(12,8))
plt.xticks(rotation=90,fontsize=12)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sales['desc_q'] = sales['Description'].value_counts()
sales.sort_values(by=['Quantity'],ascending=False)
# Out:
#          Invoice StockCode                         Description  Quantity  \
# 1065882   581483     23843         PAPER CRAFT , LITTLE BIRDIE     80995
# 587080    541431     23166      MEDIUM CERAMIC TOP STORAGE JAR     74215
# 90857     497946     37410  BLACK AND WHITE PAISLEY FLOWER MUG     19152
# 127168    501534     21091         SET/6 WOODLAND PAPER PLATES     12960
# 127166    501534     21099         SET/6 STRAWBERRY PAPER CUPS     12960
# ...          ...       ...                                 ...       ...
# 303996    519017     22759                                 NaN     -9600
# 750991    556691     23005        printing smudges/thrown away     -9600
# 750990    556690     23005        printing smudges/thrown away     -9600
# 587085   C541433     23166      MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 1065883  C581484     23843         PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                  InvoiceDate  Price  Customer ID         Country  desc_q
# ...

# %%
df = sales.groupby(by="Description", dropna=False).sum()
df = df.sort_values(by='Quantity',ascending=False)
df = df.head()
df
# Out:
#                                     Quantity     Price  Customer ID  desc_q
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     108545    298.18   14628933.0     0.0
# WHITE HANGING HEART T-LIGHT HOLDER     93050  18488.35   82666326.0     0.0
# ASSORTED COLOUR BIRD ORNAMENT          81306   5483.78   42672530.0     0.0
# JUMBO BAG RED RETROSPOT                78090   8230.47   42448849.0     0.0
# BROCADE RING PURSE                     70700    317.63    6362283.0     0.0

# %%
df = pd.DataFrame({'a':[np.nan,2,np.nan],'b':[11,np.nan,33],'c':[np.nan,222,333]})

# %%
df
# Out:
#      a     b      c
# 0  NaN  11.0    NaN
# 1  2.0   NaN  222.0
# 2  NaN  33.0  333.0

# %%
e. will fill all the Nan values according to key, 
value pairs of replacement= {'a': 0, 'b': 'unknown', 'c': 99} 
where 'Name', 'Gender' and 'column_c' are the column names.
# Out:
#   Input In [89]
#     a. df['Gender'].isna().sum() gives the number of null values in the column "Gender".
#                                  ^
# SyntaxError: invalid syntax

# %%
replacement= {'a': 0, 'b': 'unknown', 'c': 99}

# %%
df.fillna(value=replacement)
# Out:
#      a        b      c
# 0  0.0     11.0   99.0
# 1  2.0  unknown  222.0
# 2  0.0     33.0  333.0

# %%
df = pd.read_csv('sales_dataset.csv')
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df = pd.read_csv('sales_dataset.csv')
df['time'] = pd.to_datetime(df['InvoiceDate'])
df['dates'] = df['time'].dt.date
df['total_sales'] = df['Price']*df['Quantity']
df = df.groupby('dates').sum()
df = df.sort_values(by='Price',ascending=False)
df
# Out:
#             Quantity       Price  Customer ID  total_sales
# dates
# 2010-12-07     49990  170304.180   34987570.0    90118.100
# 2010-06-17     13434   73706.430   24556454.0    23993.610
# 2010-10-05     30863   67819.400   38734152.0    53656.670
# 2011-12-05     44119   57195.740   51763938.0    57751.320
# 2010-03-23     54411   52515.170   17523377.0    32491.970
# ...              ...         ...          ...          ...
# 2011-02-06      2048     799.450    4357107.0     3457.110
# 2011-08-12     11962   -6946.440   10644642.0    10049.480
# 2010-10-20     24152  -29374.970   34568370.0     5799.660
# 2010-07-19     18488  -38702.940   18551953.0   -13595.880
# 2010-04-29     17207  -44990.049   26008228.0   -22212.609
#
# [604 rows x 4 columns]

# %%
df['time'] = pd.to_datetime(df['InvoiceDate'])
df['dates'] = df['time'].dt.date
df = df.groupby('dates').sum().sort_values(by='Price',ascending=False)
df['total_sales'] = df['Quantity']*df['Price']
df.sort_values(by='total_sales',ascending=False)
# Out:
#             Quantity       Price  Customer ID   total_sales
# dates
# 2010-12-07     49990  170304.180   34987570.0  8.513506e+09
# 2010-09-27    123366   39705.110   28697073.0  4.898261e+09
# 2010-03-23     54411   52515.170   17523377.0  2.857403e+09
# 2011-12-05     44119   57195.740   51763938.0  2.523419e+09
# 2010-10-05     30863   67819.400   38734152.0  2.093110e+09
# ...              ...         ...          ...           ...
# 2010-08-13    -31437    6050.400   13156556.0 -1.902064e+08
# 2010-09-28    -63783   10607.970   33552762.0 -6.766082e+08
# 2010-10-20     24152  -29374.970   34568370.0 -7.094643e+08
# 2010-07-19     18488  -38702.940   18551953.0 -7.155400e+08
# 2010-04-29     17207  -44990.049   26008228.0 -7.741438e+08
#
# [604 rows x 4 columns]

# %%
plt.hist(df['year'])
# Out:
# (array([ 18.,  38.,  47.,  61., 104., 201., 248., 259., 263., 226.]),
#  array([1976., 1980., 1984., 1988., 1992., 1996., 2000., 2004., 2008.,
#         2012., 2016.]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df['year'],bins=4)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
sns.kdeplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
sns.boxplot(y=df['year'])
# Out:
# <AxesSubplot:ylabel='year'>
