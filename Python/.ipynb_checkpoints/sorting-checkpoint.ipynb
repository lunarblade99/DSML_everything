# %% [markdown]
# ## 1. HEAP SORT

# %% [markdown]
# **`Heap Sort:`** asd asd asd

# %%
def heapify(arr, n, i):
    largest = i
    left = 2 * i + 1
    right = 2 * i + 2

    if left < n and arr[left] > arr[largest]:
        largest = left

    if right < n and arr[right] > arr[largest]:
        largest = right

    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)


def heap_sort(arr):
    n = len(arr)

    # Build max heap
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)

    # Extract elements from the heap
    for i in range(n - 1, 0, -1):
        arr[0], arr[i] = arr[i], arr[0]  # Swap root (maximum value) with last element
        heapify(arr, i, 0)  # Heapify the reduced heap

# Test the algorithm
numbers = [64, 34, 25, 12, 22, 11, 90]
print("Original array:", numbers)

heap_sort(numbers)

print("Sorted array:", numbers)
# Out:
# Original array: [64, 34, 25, 12, 22, 11, 90]
# Sorted array: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# ## 2. MERGE SORT

# %% [markdown]
# **`Merge Sort:`** split and merge - write different functions for both

# %% [markdown]
# ![image.png](attachment:6ca20259-e2ee-4b0d-9a89-78278b4c4e9f.png)

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = merge_sort(arr[:mid])
    right_half = merge_sort(arr[mid:])

    return merge(left_half, right_half)


def merge(left, right):
    merged = []
    i, j = 0, 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            merged.append(left[i])
            i += 1
        else:
            merged.append(right[j])
            j += 1

    merged.extend(left[i:])
    merged.extend(right[j:])

    return merged


# Example usage
my_array = [5, 2, 8, 12, 1]
sorted_array = merge_sort(my_array)
print(sorted_array)

# %% [markdown]
# ## 3. QUICK SORT

# %% [markdown]
# **`Quick Sort:`** pick a pivot element and arrange the cards accordingly

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    smaller = [num for num in arr if num < pivot]
    equal = [num for num in arr if num == pivot]
    larger = [num for num in arr if num > pivot]

    return quick_sort(smaller) + equal + quick_sort(larger)


# Example usage
my_array = [5, 2, 8, 12, 1]
sorted_array = quick_sort(my_array)
print(sorted_array)
# Out:
# [1, 2, 5, 8, 12]

# %% [markdown]
# ## 4. RADIX SORT

# %% [markdown]
# ## 5. INSERTION SORT

# %% [markdown]
# **`Insertion Sort:`** Inserting the next element in best position possible

# %% [markdown]
# ![image.png](attachment:33104341-4b6a-439c-9a0f-aeb2c9c97779.png)

# %%
def insertion_sort(arr):
    # Traverse through 1 to len(arr)
    for i in range(1, len(arr)):
        key = arr[i]  # Select the current element to be inserted
        j = i - 1  # Initialize a variable to compare elements before the current position
        # Move elements of arr[0..i-1] that are greater than key to one position ahead
        # of their current position
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]  # Shift elements to the right
            j -= 1
        arr[j + 1] = key  # Insert the current element at its correct position in sorted sequence

# Example usage
my_array = [7,4,5,2]
insertion_sort(my_array)
print(my_array)
# Out:
# [2, 4, 5, 7]

# %% [markdown]
# ## 6. SELECTION SORT

# %% [markdown]
# **`Selection Sort:`** Selecting the smallest and swapping it immediately

# %% [markdown]
# ![image.png](attachment:72436892-18a8-4034-9e9b-4284523664a7.png)

# %%
def selection_sort(arr):
    # Traverse through the entire array
    for i in range(len(arr)):
        # Find the minimum element in the unsorted part of the array
        min_idx = i
        for j in range(i + 1, len(arr)):
            if arr[j] < arr[min_idx]:
                min_idx = j

        # Swap the minimum element with the first element in the unsorted part
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
# Example usage
my_array = [5, 2, 8, 12, 1]
selection_sort(my_array)
print(my_array)
# Out:
# [1, 2, 5, 8, 12]

# %% [markdown]
# ## 7. BUBBLE SORT

# %% [markdown]
# **`Bubble Sort:`** elements are like bubbles coming up

# %% [markdown]
# To optimize it further set a Flag <br>
# Flag to check if any swaps occur in this pass <br>
# If it does not then break out from the loop <br>

# %%
def bubble_sort(arr):
    n = len(arr)
    # Traverse through all array elements
    for i in range(n - 1):
        # Last i elements are already in place
        for j in range(0, n - i - 1):
            # Swap if the element found is greater than the next element
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

print(bubble_sort([64, 34, 25, 12, 22, 11, 90]))
# Out:
# [11, 12, 22, 25, 34, 64, 90]
